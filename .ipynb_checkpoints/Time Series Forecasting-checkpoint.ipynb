# %%
import numpy as np
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %%
# Futures contract on the Yen-dollar exchange rate:
# This is the continuous chain of the futures contracts that are 1 month to expiration
yen_futures = pd.read_csv(
    Path("yen.csv"), index_col="Date", infer_datetime_format=True, parse_dates=True
)
yen_futures.head()
# Out:
#               Open    High     Low    Last  Change  Settle  Volume  \
# Date
# 1976-08-02  3398.0  3401.0  3398.0  3401.0     NaN  3401.0     2.0
# 1976-08-03  3401.0  3401.0  3401.0  3401.0     NaN  3401.0     0.0
# 1976-08-04  3401.0  3401.0  3401.0  3401.0     NaN  3401.0     0.0
# 1976-08-05  3401.0  3401.0  3401.0  3401.0     NaN  3401.0     0.0
# 1976-08-06  3401.0  3401.0  3401.0  3401.0     NaN  3401.0     0.0
#
#             Previous Day Open Interest
# Date
# 1976-08-02                         1.0
# 1976-08-03                         1.0
# 1976-08-04                         1.0
# 1976-08-05                         1.0
# 1976-08-06                         1.0

# %%
# Trim the dataset to begin on January 1st, 1990
yen_futures = yen_futures.loc["1990-01-01":, :]
yen_futures.head()
# Out:
#               Open    High     Low    Last  Change  Settle   Volume  \
# Date
# 1990-01-02  6954.0  6954.0  6835.0  6847.0     NaN  6847.0  48336.0
# 1990-01-03  6877.0  6910.0  6865.0  6887.0     NaN  6887.0  38206.0
# 1990-01-04  6937.0  7030.0  6924.0  7008.0     NaN  7008.0  49649.0
# 1990-01-05  6952.0  6985.0  6942.0  6950.0     NaN  6950.0  29944.0
# 1990-01-08  6936.0  6972.0  6936.0  6959.0     NaN  6959.0  19763.0
#
#             Previous Day Open Interest
# Date
# 1990-01-02                     51473.0
# 1990-01-03                     53860.0
# 1990-01-04                     55699.0
# 1990-01-05                     53111.0
# 1990-01-08                     52072.0

# %%
# Plot just the "Settle" column from the dataframe:
yen_futures['Settle'].plot.line(legend=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import statsmodels.api as sm

# Apply the Hodrick-Prescott Filter by decomposing the "Settle" price into two separate series:
ts_noise, ts_trend = sm.tsa.filters.hpfilter(yen_futures['Settle'])
ts_noise = ts_noise.rename(columns={'Settle_noise':'Noise'})
ts_trend = ts_trend.rename(columns={'Settle_trend': 'Trend'})

# %%
# Create a dataframe of just the settle price, and add columns for "noise" and "trend" series from above:
df_yen = yen_futures[['Settle']]
df_yen['noise'] = ts_noise
df_yen['trend'] = ts_trend

df_yen.head()
# Out:
# C:\Users\rober\AppData\Local\anaconda3\envs\pyvizenv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\rober\AppData\Local\anaconda3\envs\pyvizenv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#             Settle      noise        trend
# Date
# 1990-01-02  6847.0 -61.503967  6908.503967
# ...

# %%
# Plot the Settle Price vs. the Trend for 2015 to the present
df_yen.plot(
    y = ['Settle', 'trend'],
    figsize = [20,10],
    title = 'Settle vs Trend',
    legend=True)
# Out:
# <AxesSubplot:title={'center':'Settle vs Trend'}, xlabel='Date'>

# %%
# Plot the Settle Noise
ts_noise.plot(figsize=[10,5])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
print("Based on the plots above, I would buy Yen due to it's consistent growing trend over the past couple of decades.\n"
     "There also appears to have volatile periods in which big profits could be made.")
# Out:
# Based on the plots above, I would buy Yen due to it's consistent growing trend over the past couple of decades.
# There also appears to have volatile periods in which big profits could be made.

# %%
# Create a series using "Settle" price percentage returns, drop any nan"s, and check the results:
# (Make sure to multiply the pct_change() results by 100)
# In this case, you may have to replace inf, -inf values with np.nan"s
returns = (yen_futures[["Settle"]].pct_change() * 100)
returns = returns.replace(-np.inf, np.nan).dropna()
returns.tail()
# Out:
#               Settle
# Date
# 2019-10-09 -0.410601
# 2019-10-10 -0.369458
# 2019-10-11 -0.564304
# 2019-10-14  0.151335
# 2019-10-15 -0.469509

# %%
from statsmodels.tsa.arima_model import ARMA

# Estimate and ARMA model using statsmodels (use order=(2, 1))
model = ARMA(returns.values, order=(2,1))

# Fit the model and assign it to a variable called results
results = model.fit()

# Output model summary results:
results.summary()
# Out:
# C:\Users\rober\AppData\Local\anaconda3\envs\pyvizenv\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
# ...

# %%
# Plot the 5 Day Returns Forecast
pd.DataFrame(results.forecast(steps=5)[0]).plot(title='5 Day Returns Forecast')
# Out:
# <AxesSubplot:title={'center':'5 Day Returns Forecast'}>

# %%
print("However, the p-score, for a 5 Day forecast of returns, appears to be increasing which could \ntranslate into higher risks when buying Yen.")
# Out:
# However, the p-score, for a 5 Day forecast of returns, appears to be increasing which could
# translate into higher risks when buying Yen.

# %%
from statsmodels.tsa.arima_model import ARIMA

# Estimate and ARIMA Model:
# Hint: ARIMA(df, order=(p, d, q))
model_2 = ARIMA(yen_futures.Settle, order=(5,1,1))

# Fit the model
results = model_2.fit()

# Output model summary results:
results.summary()
# Out:
# C:\Users\rober\AppData\Local\anaconda3\envs\pyvizenv\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %%
pd.DataFrame(results.forecast(steps=5)[0]).plot(title='5 Day Price Forecast')
# Out:
# <AxesSubplot:title={'center':'5 Day Price Forecast'}>

# %%
from arch import arch_model

model = arch_model(returns, mean='Zero', vol="GARCH", p=2, q=1)
results = model.fit(disp='off')
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        Zero Mean - GARCH Model Results
# ...
# Dep. Variable:                 Settle   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -7461.93
# Distribution:                  Normal   AIC:                           14931.9
# Method:            Maximum Likelihood   BIC:                           14959.6
#                                         No. Observations:                 7514
# Date:                Tue, Nov 17 2020   Df Residuals:                     7510
# Time:                        19:22:53   Df Model:                            4
#                                Volatility Model
# ...
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# ...

# %%
# Find the last day of the dataset
last_day = returns.index.max().strftime('%Y-%m-%d')
last_day
# Out:
# '2019-10-15'

# %%
# Create a 5 day forecast of volatility
forecast_horizon = 5

# Start the forecast using the last_day calculated above
forecasts = results.forecast(start=last_day, horizon=forecast_horizon)

# %%
# Annualize the forecast
intermediate = np.sqrt(forecasts.variance.dropna() * 252)
intermediate.head()
# Out:
#                  h.1       h.2       h.3       h.4       h.5
# Date
# 2019-10-15  7.434048  7.475745  7.516867  7.557426  7.597434

# %%
# Transpose the forecast so that it is easier to plot
final = intermediate.dropna().T
final.head()
# Out:
# Date  2019-10-15
# h.1     7.434048
# h.2     7.475745
# h.3     7.516867
# h.4     7.557426
# h.5     7.597434

# %%
# Plot the final forecast
final.plot(title="5 Day Forecast of Volatility")
# Out:
# C:\Users\rober\AppData\Local\anaconda3\envs\pyvizenv\lib\site-packages\pandas\plotting\_core.py:396: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:title={'center':'5 Day Forecast of Volatility'}>

# %%
print("Based on the model evaluation, I would not feel confident in using these models for trading\n due to the increasing volatility provided from our data.")
# Out:
# Based on the model evaluation, I would not feel confident in using these models for trading
#  due to the increasing volatility provided from our data.
